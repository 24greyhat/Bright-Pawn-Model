# %% [markdown]
# ## Importing Modules & Loading Data

# %%
# Install requirements
# %pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 4/6 [httpx]  WARNING: The script httpx is installed in '/Library/Frameworks/Python.framework/Versions/3.14/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [realtime-crypto]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing modules
from realtime_crypto import RealTimeCrypto
import asyncio

tracker = RealTimeCrypto()

# %%
bitcoin = tracker.get_coin("bitcoin")

year_prices = bitcoin.get_history("1y")

stats = bitcoin.get_statistics()


stats.get_price_change("24h")
